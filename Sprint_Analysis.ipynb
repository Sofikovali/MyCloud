# %%
import pandas as pd
data = pd.read_excel('Sprint_a.xlsx') #если нет заголовков, и разделитель не запятушка, а табуляшка

# %%
data
# Out:
#     Week      Date   Ideal  Real
# 0      1 2018-01-08   13.5  13.5
# 1      2 2018-01-15   13.5  13.0
# 2      3 2018-01-22   15.0  15.0
# 3      4 2018-01-29   13.5  12.0
# 4      5 2018-02-05   13.5  12.0
# 5      6 2018-02-12   15.0  12.0
# 6      7 2018-02-19   15.0  15.0
# 7      8 2018-02-26   13.5  12.0
# 8      9 2018-03-05   13.5  12.0
# 9     10 2018-03-12   13.5  12.0
# 10    11 2018-03-19   13.5  12.0
# 11    12 2018-03-26   13.5  12.0
# 12    13 2018-04-02   13.5  12.0
# 13    14 2018-04-09   13.5  13.5
# 14    15 2018-04-16   13.5  12.0
# 15    16 2018-04-23   13.5  12.0
# 16    17 2018-04-30   13.5  13.5
# 17    18 2018-05-07   13.5  12.0
# 18    19 2018-05-14   13.5  13.5
# 19    20 2018-05-21   13.5  12.0
# 20    21 2018-05-28   13.5  10.0
# 21    22 2018-06-04   13.5  10.0
# 22    23 2018-06-11   13.5  10.0
# 23    24 2018-06-18   13.5  10.0
# 24    25 2018-06-25   13.5  10.0
# 25    26 2018-07-02   13.5  10.0
# 26    27 2018-07-09   13.5  10.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot( data['Week'],data['Real'], marker = 'o')
plt.plot(data['Ideal'], color='purple')
plt.legend ( ("реальность", "план") )
plt.ylabel('Сторипоинты')
plt.xlabel('недели')
# Out:
# Text(0.5,0,'недели')
